# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.analysis import load_tomtom_flow

API_KEY = "3NbaZ3h8jHPHYqVxgL6tf1kvhKHUOVd"

data = load_tomtom_flow(51.05, 3.72, API_KEY)  # Gent centrum
data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 4
#       1 import sys, os
#       2 sys.path.append(os.path.abspath(".."))
#       3
# ----> 4 from src.analysis import load_tomtom_flow
#       5
#       6 API_KEY = "3NbaZ3h8jHPHYqVxgL6tf1kvhKHUOVd"
#       7
#
# ImportError: cannot import name 'load_tomtom_flow' from 'src.analysis' (c:\Art Life\traffic-insight-assistant\src\analysis.py)
